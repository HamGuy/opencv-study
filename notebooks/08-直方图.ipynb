# %% [markdown]
# #直方图
#
# 使用 `cv2.calcHist(images, channels,mask,histSize, ranges)` 函数统计直方图所需数据
#
# • images：原图像图像格式为uint8或float32。当传入函数时应用中括号口括来例如img]
# • channels：同样用中括号括来它会告函数我们统幅图像的直方图。如果入图像是灰度图它的值就是10如果是彩色图像的传入的参数可以是[OI11121它们分别
# 対座着BGR。
# • mask:掩模图像。统整幅图像的直方图就把它为None。但是如果你根统图像某一分的直方图的你就制作一个掩模图像并使用它。
# • histsize:BIN的数目。也应用中括号括来
# • ranges:像素値范国常力「02561

# %%
# notebook 里自动绘制图像
# %matplotlib inline 

import cv2
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

# 读取图像
img = cv2.imread('../imgs/09.png',0)
grayImg = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
# 绘制图像
plt.imshow(grayImg)

# %%
# 直方图
hist = cv2.calcHist([grayImg],[0],None,[256],[0,256])
hist.shape
# Out:
# (256, 1)

# %%
plt.hist(img.ravel(),256)
plt.show()

# %%
# 通道拆分
img2 = cv2.imread('../imgs/09.png')
color = ('b','g','r')
for i,col in enumerate(color):
    histr = cv2.calcHist([img2],[i],None,[256],[0,256])
    plt.plot(histr,color=col)
    plt.xlim(0,256)

# %%
# Mask - 掩码，PS蒙版？

mask = np.zeros(img2.shape[:2],np.uint8)
mask[1000:3000,1000:4000] = 255
plt.imshow(mask)

# %%
maksedImg = cv2.bitwise_and(img2,img2, mask=mask)
plt.imshow(maksedImg)

# %%
histFull = cv2.calcHist([img2],[0],None,[256],[0,256])
histMask = cv2.calcHist([img2],[0],mask,[256],[0,256])
plt.plot(histFull)
plt.plot(histMask)
plt.xlim([0,256])
plt.show()

# %%
#直方图均衡化 ？？？

自适应均衡化
