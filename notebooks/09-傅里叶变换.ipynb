# %% [markdown]
# ##### 傅里叶变换的作用
#
# https://zhuanlan.zhihu.com/p/19763358
#
# 1. 高频：变化剧烈的灰度分量，例如边界
# 2.  低频：变化缓慢的灰度分量，例如一片大海
#
# 淲波
# 1. 低通滤波器：只保留低频，会使得图像模糊
# 2. 高通滤波器：只保留高频，会使得图像細节增强
#
# opencv中主要就是cv2.dft()和cv2.idft)，輸入圖像需要先裝換成np.float32格式。
#
# 得到的结果中频率为0的部分会在左上角，通常要转换到中心位置，可以通过shift变换来实现。
#
# cv2.dft0返回的结果是双通道的（买部，虛部），通常还需要转换成图像格式才能展示(0,255）。

# %%
# notebook 里自动绘制图像
# %matplotlib inline 

import cv2
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

# 读取图像
img = cv2.imread('../imgs/09.png')
# 绘制图像
plt.imshow(img)
